# %% [markdown]
# # IPython
# Entwicklungsumgebung, in der Ergebnisse in Zellen gespeichert werden
#
# Ergebnisse von vorherigen Zellen können später in anderen Zellen verwendet werden
#
# - Weitere Features:
#     - Aufzählungen
#     - Überschriften
#     - __Fetter Text__
#     - _Kursiver Text_
# - Imports über mehrere Zellen
# - Diagramme/Tabellen darstellen

# %%
x = 5

# %%
x*2
# Out:
# 10

# %%
x = x*2

# %%
x
# Out:
# 10

# %% [markdown]
# ## Navigation mit Zellen
# - Enter -> in Zelle gehen
# - Escape -> Zelle verlassen
# - Wenn Zelle verlassen
#     - Pfeiltasten navigieren
#     - M -> MarkDown(Text) Zelle
#     - Y -> Code Zelle
# - Wenn in Zelle
#     - Schreiben
#     - Shift+Enter -> Zelle Ausführen & Neue Zelle darunter

# %%
# In Code Zellen funktionieren Kommentare wie in normalem Pyhton
# Es ist ja auch einfacher Python Code
name = "Bernd"
name
# Out:
# 'Bernd'

# %% [markdown]
# ## Tabelle darstellen

# %%
import pandas as pd

# %%
pd.DataFrame({"Spalte1": [1,2,3], "Spalte2": [4,5,6], "Spalte3": [7,8,9]})
# Out:
#    Spalte1  Spalte2  Spalte3
# 0        1        4        7
# 1        2        5        8
# 2        3        6        9

# %% [markdown]
# ## Diagramme darstellen

# %%
import matplotlib.pyplot as plt

# %%
y = [3, 9, 1, 7, 24, 45]
plt.plot(y)
